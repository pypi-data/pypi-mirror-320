# %%
from environmental_risk_metrics import EndangeredSpecies
import logging
import geopandas as gpd

# Configure logging to display in Jupyter
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    force=True,  # This ensures the configuration is applied even if logging was previously configured
)
logger = logging.getLogger(__name__)


polygon = {
    "type": "Feature",
    "properties": {},
    "geometry": {
        "coordinates": [
            [
                [10.235198982658801, 51.42076009745068],
                [10.236477278753114, 51.41697045550828],
                [10.244461712820623, 51.41823370440062],
                [10.242888425319222, 51.4220355049745],
                [10.235198982658801, 51.42076009745068],
            ]
        ],
        "type": "Polygon",
    },
}

crs = "EPSG:4326"
gdf = gpd.GeoDataFrame.from_features([polygon])
endangered_species = EndangeredSpecies()

endangered_species.get_species_stats(polygon, polygon_crs=crs, buffer_meters=10000)
# Out:
#       kingdom          class                  species iucnRedListCategory
# 0    Animalia       Mammalia         Sciurus vulgaris       Least Concern
# 1    Animalia           Aves              Buteo buteo       Least Concern
# 2       Fungi  Pezizomycetes       Morchella vulgaris       Not Evaluated
# 3    Animalia        Insecta            Osmia cornuta       Not Evaluated
# 4     Plantae  Magnoliopsida            Silene dioica       Not Evaluated
# ..        ...            ...                      ...                 ...
# 287   Plantae  Magnoliopsida  Viburnum rhytidophyllum       Not Evaluated
# 289   Plantae  Magnoliopsida      Trifolium campestre       Not Evaluated
# 290   Plantae  Magnoliopsida              Rosa canina       Not Evaluated
# 291   Plantae  Magnoliopsida       Euonymus europaeus       Least Concern
# 292   Plantae  Magnoliopsida           Acer campestre       Least Concern
#
# [198 rows x 4 columns]
