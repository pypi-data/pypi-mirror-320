# %% [markdown]
# # Automatizing new matches downloads

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from io import StringIO
import time
import re

# %% [markdown]
# ### Obtaining individual data in the website

# %%
class FBREFData:
    def __init__(self, base_url):
        self.base_url = base_url
        self.links = []
        self.gameweeks = []
        self.get_links()
        self.get_gameweek()
        self.create_matches_csv()
    
    def get_links(self):
        response = requests.get(self.base_url)
        soup = BeautifulSoup(response.text, 'html.parser')

        report_cells = soup.find_all('td', {'data-stat': 'match_report'})

        for idx, cell in enumerate(report_cells):
            link = cell.find('a')
            if link:
                url = link['href']
                self.links.append(f'https://fbref.com{url}')

            # Stop after getting x links
            if len(self.links) >= 3:
                break
            
            time.sleep(6)

        df_links = pd.DataFrame(self.links, columns=['link'])
        df_links.to_csv('links.csv', index=False)
        print(f"Links saved in links.csv")
    
    def get_gameweek(self):
        response = requests.get(self.base_url)
        soup = BeautifulSoup(response.text, 'html.parser')

        gameweek_cells = soup.find_all('th', {'data-stat': 'gameweek'})

        for idx, cell in enumerate(gameweek_cells):
            gameweek_value = cell.text.strip() if cell else 'N/A'
            self.gameweeks.append(gameweek_value)

            # Stop after getting x gameweeks
            if len(self.gameweeks) >= 4:
                break

            time.sleep(6)
        
        df_gameweeks = pd.DataFrame(self.gameweeks, columns=['gameweek'])

        df_gameweeks.to_csv('gameweeks.csv', index=False)
        print("Gameweeks saved in gameweeks.csv")

        df_gameweeks = df_gameweeks[~df_gameweeks['gameweek'].isin(['Sem.', ''])]

        df_gameweeks.to_csv('gameweeks.csv', index=False)
        
    def create_matches_csv(self):
        df_matches = pd.DataFrame({
            'date_of_match': pd.Series([None] * len(self.links), dtype='object'),  
            'hour_of_the_match': pd.Series([None] * len(self.links), dtype='object'),  
            'home_team_name': pd.Series([None] * len(self.links), dtype='object'),  
            'away_team_name': pd.Series([None] * len(self.links), dtype='object'),
            'home_trainer': pd.Series([None] * len(self.links), dtype='object'),
            'away_trainer': pd.Series([None] * len(self.links), dtype='object'),
            'stadium': pd.Series([None] * len(self.links), dtype='object'),
            'attendance': pd.Series([None] * len(self.links), dtype='object'),
            'referee': pd.Series([None] * len(self.links), dtype='object'),
            'var': pd.Series([None] * len(self.links), dtype='object'),
            'home_team_lineup': pd.Series([None] * len(self.links), dtype='object'),
            'away_team_lineup': pd.Series([None] * len(self.links), dtype='object'),
            ##     'home_team_goal_count': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'away_team_goal_count': pd.Series([0] * len(self.links), dtype='int32'),  
            #     'home_possession': pd.Series([0.0] * len(self.links), dtype='float32'),
            #     'away_possession': pd.Series([0.0] * len(self.links), dtype='float32'),  
            ##     'total_goal_count': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'total_goals_at_half_time': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'home_team_goal_count_half_time': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'away_team_goal_count_half_time': pd.Series([0] * len(self.links), dtype='int32'),
            ##     'home_team_passings': pd.Series([0] * len(self.links), dtype='int32'),
            ##     'away_team_passings': pd.Series([0] * len(self.links), dtype='int32'),
            #     'penaltis': pd.Series([0.0] * len(self.links), dtype='float32'),
            ##     'home_team_passings_success': pd.Series([0] * len(self.links), dtype='int32'),
            ##     'away_team_passings_success': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'home_team_shots': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'away_team_shots': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'home_team_shots_on_target': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'away_team_shots_on_target': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'home_team_fouls': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'away_team_fouls': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'home_team_yellow_cards': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'home_team_red_cards': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'away_team_yellow_cards': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'away_team_red_cards': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'home_team_first_half_cards': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'home_team_second_half_cards': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'away_team_first_half_cards': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'away_team_second_half_cards': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'home_team_shots_off_target': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'away_team_shots_off_target': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'home_team_corner_count': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'away_team_corner_count': pd.Series([0] * len(self.links), dtype='int32'),  
            ##     'home_ppg': pd.Series([0.0] * len(self.links), dtype='float32'),  
            ##     'away_ppg': pd.Series([0.0] * len(self.links), dtype='float32'),
            ##     'home_xg': pd.Series([0.0] * len(self.links), dtype='float32'),  
            ##     'away_xg': pd.Series([0.0] * len(self.links), dtype='float32'),  
            ##     'match_result': pd.Series([0.0] * len(self.links), dtype='float32'),
        })
        
        df_matches.to_csv('matches.csv', index=False)

    def get_statistics(self):
        try:
            df_links = pd.read_csv('links.csv')
            links = df_links['link'].tolist()

            df_matches = pd.read_csv('matches.csv')

            for idx, link in enumerate(links):
                try:
                    print(f"Processing link {idx + 1}: {link}")
                    response = requests.get(link)
                    soup = BeautifulSoup(response.text, 'html.parser')

                    match_date = "Unknown"
                    match_time = "Unknown"
                    home_team_name = "Unknown"
                    away_team_name = "Unknown"
                    home_trainer = "Unknown"
                    away_trainer = "Unknown"
                    stadium = "Unknown"
                    attendance = "Unknown"
                    referee = "Unknown"
                    var = "Unknown"
                    home_team_lineup = "Unknown"
                    away_team_lineup = "Unknown"

                    # date_of_match
                    date_element = soup.find('span', {'class': 'venuetime'})
                    if date_element:
                        match_date = date_element.get('data-venue-date', "Unknown")
                        match_time = date_element.get('data-venue-time', "Unknown")
                    df_matches.at[idx, 'date_of_match'] = match_date
                    df_matches.at[idx, 'hour_of_the_match'] = match_time

                    # home_team_name and away_team_name
                    teams_elements = soup.find_all('span', class_='teamandlogo')
                    if len(teams_elements) >= 2:
                        home_team_name = teams_elements[0].text.strip()
                        away_team_name = teams_elements[1].text.strip()
                    df_matches.at[idx, 'home_team_name'] = home_team_name
                    df_matches.at[idx, 'away_team_name'] = away_team_name

                    # home_trainer and away_trainer
                    trainers_elements = soup.find_all('div', class_='datapoint')
                    trainer_count = 0
                    for trainer_element in trainers_elements:
                        if 'Director Técnico' in trainer_element.text:
                            trainer_name = trainer_element.text.split(':')[-1].strip()
                            if trainer_count == 0:
                                home_trainer = trainer_name
                                trainer_count += 1
                            elif trainer_count == 1:
                                away_trainer = trainer_name
                                trainer_count += 1
                    df_matches.at[idx, 'home_trainer'] = home_trainer
                    df_matches.at[idx, 'away_trainer'] = away_trainer

                    # stadium
                    stadium_element = soup.find('div', class_='scorebox_meta')
                    if stadium_element:
                        stadium_info = stadium_element.find('strong', string="Sedes")
                        if stadium_info:
                            stadium = stadium_info.find_next('small').find_next('small').text.strip()
                    df_matches.at[idx, 'stadium'] = stadium

                    # attendance
                    attendance_element = soup.find('div', class_='scorebox_meta')
                    if attendance_element:
                        attendance_info = attendance_element.find('strong', string="Asistencia")
                        if attendance_info:
                            attendance = attendance_info.find_next('small').find_next('small').text.strip()
                    df_matches.at[idx, 'attendance'] = attendance

                    # referee
                    referee_element = soup.find('div', class_='scorebox_meta')
                    if referee_element:
                        referee_info = referee_element.find_next('strong', string="Autoridades")
                        if referee_info:
                            referee_span = referee_info.find_next('small').find_next('small').find('span', style="display:inline-block")
                            if referee_span:
                                referee = referee_span.text.strip()
                    df_matches.at[idx, 'referee'] = referee

                    # var
                    var_element = soup.find('div', class_='scorebox_meta')
                    if var_element:
                        var_info = var_element.find_next('strong', string="Autoridades")
                        if var_info:
                            var_span = var_info.find_next('small').find_next('small').find_next('span').find_next('span').find_next('span').find_next('span').find_next('span')
                            if var_span:
                                var = var_span.text.strip()
                    df_matches.at[idx, 'var'] = var

                    # lineup
                    lineup_elements = soup.find_all('th', string=lambda text: text and '(' in text and ')' in text)
                    if len(lineup_elements) >= 1:
                        home_match = re.search(r'\((.*?)\)', lineup_elements[0].text)
                        if home_match:
                            home_team_lineup = home_match.group(1)
                    if len(lineup_elements) >= 2:
                        away_match = re.search(r'\((.*?)\)', lineup_elements[1].text)
                        if away_match:
                            away_team_lineup = away_match.group(1)
                    df_matches.at[idx, 'home_team_lineup'] = home_team_lineup
                    df_matches.at[idx, 'away_team_lineup'] = away_team_lineup

                except Exception as e:
                    print(f"Error processing link {link}: {e}")

                time.sleep(6)

            df_matches.to_csv('matches.csv', index=False)
            print("File 'matches.csv' updated successfully.")

        except FileNotFoundError as e:
            print(f"Error: {e}. Make sure 'links.csv' and 'matches.csv' exist.")
        except Exception as e:
            print(f"Unexpected error: {e}")

# %% [markdown]
# ### Obtaining global data in the website

# %%
class MultiTableExtractor:
    def __init__(self, url, gameweek):
        self.url = url
        self.gameweek = gameweek
        self.soup = None
        self.teams_data = {}
        self.fetch_page()

    def fetch_page(self):
        response = requests.get(self.url)
        if response.status_code != 200:
            raise Exception(f"Error al acceder a la página: {response.status_code}")
        self.soup = BeautifulSoup(response.content, "html.parser")
        time.sleep(6)

    def extract_teams_ids(self):
        if not self.soup:
            raise Exception("Primero debes cargar la página con `fetch_page`.")
        
        team_imgs = self.soup.find_all('img', class_='teamlogo', src=True)
        if len(team_imgs) >= 2:
            self.teams_data = {
                "home": {
                    "id": team_imgs[0]['src'].split('/')[-1].split('.')[0],
                    "name": team_imgs[0]['alt'].split(" ")[0],
                },
                "away": {
                    "id": team_imgs[1]['src'].split('/')[-1].split('.')[0],
                    "name": team_imgs[1]['alt'].split(" ")[0],
                },
            }
        else:
            raise Exception("No se encontraron suficientes logos de equipos.")

    def extract_table(self, team_type, table_type, header_offset, columns_to_drop):
        team_id = self.teams_data[team_type]["id"]
        table_selector = f"#div_stats_{team_id}_{table_type}"
        table = self.soup.select_one(table_selector)
        if not table:
            raise Exception(f"No se encontró la tabla {table_type} para el equipo {team_type}.")
        
        headers = [th.text.strip() for th in table.find("thead").find_all("th")][header_offset:]
        rows = [
            [cell.text.strip() for cell in row.find_all(["td", "th"])]
            for row in table.find("tbody").find_all("tr")
        ]
        df = pd.DataFrame(rows, columns=headers)
        df = df.loc[:, ~df.columns.isin(columns_to_drop)]
        return df

    def process_team_data(self, team_type):
        # Columnas que se eliminarán para cada tipo de tabla
        columns_to_drop = {
            "summary": ['Ass', 'TP', 'TPint', 'TA', 'TR', 'Toques', 'Tkl', 'Int', 'Bloqueos', 'xG', 'npxG', 'xAG', 'ACT', 'ACG', 'Cmp', 'Int.', '% Cmp', 'PrgP', 'Transportes', 'PrgC', 'Att', 'Succ'],
            "passing": ['Jugador', 'núm.', 'País', 'Posc', 'Edad', 'Mín'],
            "passing_types": ['Jugador', 'núm.', 'País', 'Posc', 'Edad', 'Mín', 'Int.', 'Cmp'],
            "defense": ['Jugador', 'núm.', 'País', 'Posc', 'Edad', 'Mín'],
            "possession": ['Jugador', 'núm.', 'País', 'Posc', 'Edad', 'Mín', 'Tkld', 'Tkld%'],
            "misc": ['Jugador', 'núm.', 'País', 'Posc', 'Edad', 'Mín', 'Pcz', 'PA', 'Int', 'TklG', 'GC'],
        }

        # Inicializar tablas
        tables = {}
        for table_type, header_offset in [("summary", 7), ("passing", 9), ("passing_types", 4), ("defense", 5), ("possession", 5), ("misc", 3)]:
            tables[table_type] = self.extract_table(
                team_type, table_type, header_offset, columns_to_drop.get(table_type, [])
            )
            
        return tables

    def save_team_tables(self):
        self.extract_teams_ids()
        for team_type in ["home", "away"]:
            team_name = self.teams_data[team_type]["name"]
            team_tables = self.process_team_data(team_type)
            final_table = pd.concat(team_tables.values(), axis=1)
            final_table.to_csv(f"{self.gameweek}_{team_name}_{team_type}_team_final_table.csv", index=False)

            new_columns = ["Player", "Number", "Nationality", "Position", "Age",
                  "Minutes", "Goals", "Shots", "ShotsOnTarget", "CompletedPasses", "AttemptedPasses", 
                  "%CompletedPasses", "DistancePasses", "DistanceProgression", 
                  "ShortPasses", "AttemptedShortPasses", "%ShortCompletedPasses", 
                  "MediumPasses", "AttemptedMediumPasses", "%MediumCompletedPasses", 
                  "LongPasses", "AttemptedLongPasses", "%LlongCompletedPasses", 
                  "Assistance", "ExpectedGoalsAssistance", "ExpectedAssistance", 
                  "KeyPasses", "Last1/3Passes", "GoalAreaPasses", "GoalAreaCrosses", 
                  "GoalPasses", "LiveBallPasses", "DeadBallPasses", "FreeKick", 
                  "LongPasses", "SidePasses", "Crosses", "Strongcrosses", "Corner", 
                  "CornerIn", "CornerOut", "CornerRect", "OffsidePasses", 
                  "PassesBlocked", "Tackles", "SuccessfulTackles", "TacklesInDefense", 
                  "TacklesInMedium", "TacklesInAttack", "DribblerTackles", 
                  "AttemptedDribblerTackles", "%DribblerTacklesCompleted", 
                  "DribblerTacklesNonCompleted", "BallsBlocked", "ShotsBlocked", 
                  "PassesBlocked", "Interceptions", "Tackles+Interceptions", 
                  "Clearances", "MistakesRivalShots", "Touches", 
                  "OwnPenaltyAreaTouches", "TouchesInDefense", "TouchesInMedium",
                  "AttemptedDribbles" , "DribblesCompleted", "%DribblesCompleted",
                  "TouchesInAttack", "AwayPenaltyAreaTouches", "LiveBallTouches", 
                  "BallCarries","DistanceCarried", "ForwardDistanceCarried", 
                  "ForwardCarries", "CarriesInAttack", "AwayPenaltyAreaCarries",
                  "LostControlCarries", "LostCarries", "PassesReception", 
                  "AttackPassesReception", "YellowCards", "RedCards", 
                  "SecondYellowCards", "Fouls", "Offside", "Penalties",
                  "PenaltiesConceded", "LostBallRecoveries", "AerialsWon", 
                  "AerialsLost", "%AerialsWon"
                  ]

            # Cambiar los nombres de las columnas del 0 al 89
            final_table.columns = new_columns

            # Guardar el CSV actualizado
            output_filename = f"{self.gameweek}_{team_name}_{team_type}_team_final_table.csv"
            final_table.to_csv(output_filename, index=False)

            print(f"Tabla del equipo {team_type} guardada como {output_filename}")
    
    def process_links_and_gameweeks(self, links_file, gameweeks_file):
        links_df = pd.read_csv(links_file)
        gameweeks_df = pd.read_csv(gameweeks_file)
        
        for index, link in enumerate(links_df['link']):
            gameweek = gameweeks_df.iloc[index]['gameweek']
            print(f"Procesando URL: {link} con Gameweek: {gameweek}")
            extractor = MultiTableExtractor(link, gameweek)
            extractor.save_team_tables()

# %% [markdown]
# ### Full process

# %%
'''base_url = 'https://fbref.com/es/comps/12/2023-2024/horario/Marcadores-y-partidos-de-2023-2024-La-Liga'

extractor = MultiTableExtractor(base_url, None)
extractor.process_links_and_gameweeks('links.csv', 'gameweeks.csv')'''
# Out:
# Procesando URL: https://fbref.com/es/partidos/30d3212e/Almeria-Rayo-Vallecano-Agosto-11-2023-La-Liga con Gameweek: 1
# Tabla del equipo home guardada como 1_Almería_home_team_final_table.csv
# Tabla del equipo away guardada como 1_Rayo_away_team_final_table.csv
# Procesando URL: https://fbref.com/es/partidos/525758cc/Sevilla-Valencia-Agosto-11-2023-La-Liga con Gameweek: 1
# Tabla del equipo home guardada como 1_Sevilla_home_team_final_table.csv
# Tabla del equipo away guardada como 1_Valencia_away_team_final_table.csv
# Procesando URL: https://fbref.com/es/partidos/706596c6/Real-Sociedad-Girona-Agosto-12-2023-La-Liga con Gameweek: 1
# Tabla del equipo home guardada como 1_Real_home_team_final_table.csv
# Tabla del equipo away guardada como 1_Girona_away_team_final_table.csv

# %%
def run_full_process():
    base_url = 'https://fbref.com/es/comps/12/2023-2024/horario/Marcadores-y-partidos-de-2023-2024-La-Liga'
    
    fbref_data_instance = FBREFData(base_url)
    fbref_data_instance.get_statistics()
    
    extractor = MultiTableExtractor(base_url, None)
    extractor.process_links_and_gameweeks('links.csv', 'gameweeks.csv')

# %%
run_full_process()
# Out:
# Links saved in links.csv
# Gameweeks saved in gameweeks.csv
# Processing link 1: https://fbref.com/es/partidos/30d3212e/Almeria-Rayo-Vallecano-Agosto-11-2023-La-Liga
# C:\Users\julio\AppData\Local\Temp\ipykernel_6768\1318555541.py:142: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2023-08-11' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_matches.at[idx, 'date_of_match'] = match_date
# C:\Users\julio\AppData\Local\Temp\ipykernel_6768\1318555541.py:143: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '19:30' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_matches.at[idx, 'hour_of_the_match'] = match_time
# C:\Users\julio\AppData\Local\Temp\ipykernel_6768\1318555541.py:150: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Almería' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_matches.at[idx, 'home_team_name'] = home_team_name
# C:\Users\julio\AppData\Local\Temp\ipykernel_6768\1318555541.py:151: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Rayo Vallecano' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_matches.at[idx, 'away_team_name'] = away_team_name
# C:\Users\julio\AppData\Local\Temp\ipykernel_6768\1318555541.py:165: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Vicente Moreno' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_matches.at[idx, 'home_trainer'] = home_trainer
# C:\Users\julio\AppData\Local\Temp\ipykernel_6768\1318555541.py:166: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Francisco' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_matches.at[idx, 'away_trainer'] = away_trainer
# C:\Users\julio\AppData\Local\Temp\ipykernel_6768\1318555541.py:174: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Power Horse Stadium, Almería' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_matches.at[idx, 'stadium'] = stadium
# C:\Users\julio\AppData\Local\Temp\ipykernel_6768\1318555541.py:182: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14,837' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_matches.at[idx, 'attendance'] = attendance
# C:\Users\julio\AppData\Local\Temp\ipykernel_6768\1318555541.py:192: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Javier Alberola (Árbitro)' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_matches.at[idx, 'referee'] = referee
# C:\Users\julio\AppData\Local\Temp\ipykernel_6768\1318555541.py:202: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Santiago Jaime (VAR)' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_matches.at[idx, 'var'] = var
# C:\Users\julio\AppData\Local\Temp\ipykernel_6768\1318555541.py:214: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4-2-3-1' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_matches.at[idx, 'home_team_lineup'] = home_team_lineup
# C:\Users\julio\AppData\Local\Temp\ipykernel_6768\1318555541.py:215: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4-2-3-1' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_matches.at[idx, 'away_team_lineup'] = away_team_lineup
# Processing link 2: https://fbref.com/es/partidos/525758cc/Sevilla-Valencia-Agosto-11-2023-La-Liga
# Processing link 3: https://fbref.com/es/partidos/706596c6/Real-Sociedad-Girona-Agosto-12-2023-La-Liga
# File 'matches.csv' updated successfully.
# Procesando URL: https://fbref.com/es/partidos/30d3212e/Almeria-Rayo-Vallecano-Agosto-11-2023-La-Liga con Gameweek: 1
# Tabla del equipo home guardada como 1_Almería_home_team_final_table.csv
# Tabla del equipo away guardada como 1_Rayo_away_team_final_table.csv
# Procesando URL: https://fbref.com/es/partidos/525758cc/Sevilla-Valencia-Agosto-11-2023-La-Liga con Gameweek: 1
# Tabla del equipo home guardada como 1_Sevilla_home_team_final_table.csv
# Tabla del equipo away guardada como 1_Valencia_away_team_final_table.csv
# Procesando URL: https://fbref.com/es/partidos/706596c6/Real-Sociedad-Girona-Agosto-12-2023-La-Liga con Gameweek: 1
# Tabla del equipo home guardada como 1_Real_home_team_final_table.csv
# Tabla del equipo away guardada como 1_Girona_away_team_final_table.csv

# %% [markdown]
# ### Funcion para ver cuanto tiempo de espera

# %%
import requests
import time
from bs4 import BeautifulSoup

def fetch_page_with_retry(url):
    # Intentamos hacer la solicitud
    response = requests.get(url)

    # Si el código de estado es 429 (Too Many Requests), esperamos
    if response.status_code == 429:
        retry_after = response.headers.get('Retry-After', 60)  # Si no hay "Retry-After", esperamos 60 segundos
        print(f"Demasiadas solicitudes. Espera {retry_after} segundos antes de intentar de nuevo.")
        time.sleep(int(retry_after))  # Esperamos el tiempo indicado
        return fetch_page_with_retry(url)  # Hacemos la solicitud nuevamente después de esperar

    # Si la solicitud es exitosa (200 OK), procesamos la página
    if response.status_code == 200:
        return response.text  # Devolvemos el contenido de la página

    # Si no es un código 200 o 429, retornamos None
    print(f"Error al acceder a la página: {response.status_code}")
    return None

def extract_match_reports(url):
    page_content = fetch_page_with_retry(url)
    
    if page_content:
        soup = BeautifulSoup(page_content, 'html.parser')
        informes = soup.find_all('td', {'data-stat': 'match_report'})
        enlaces = ['https://fbref.com' + informe.find('a')['href'] for informe in informes if informe.find('a')]
        
        for enlace in enlaces:
            print(enlace)
    else:
        print("No se pudo obtener el contenido de la página.")

# URL de ejemplo
url = 'https://fbref.com/es/comps/12/2023-2024/horario/Marcadores-y-partidos-de-2023-2024-La-Liga'

# Llamamos a la función
extract_match_reports(url)
# Out:
# https://fbref.com/es/partidos/30d3212e/Almeria-Rayo-Vallecano-Agosto-11-2023-La-Liga
# https://fbref.com/es/partidos/525758cc/Sevilla-Valencia-Agosto-11-2023-La-Liga
# https://fbref.com/es/partidos/706596c6/Real-Sociedad-Girona-Agosto-12-2023-La-Liga
# https://fbref.com/es/partidos/8c6555db/Las-Palmas-Mallorca-Agosto-12-2023-La-Liga
# https://fbref.com/es/partidos/c31f0a31/Athletic-Club-Real-Madrid-Agosto-12-2023-La-Liga
# https://fbref.com/es/partidos/8689fb39/Celta-Vigo-Osasuna-Agosto-13-2023-La-Liga
# https://fbref.com/es/partidos/b8258a85/Villarreal-Real-Betis-Agosto-13-2023-La-Liga
# https://fbref.com/es/partidos/b34ff242/Getafe-Barcelona-Agosto-13-2023-La-Liga
# https://fbref.com/es/partidos/c36e6859/Cadiz-Alaves-Agosto-14-2023-La-Liga
# https://fbref.com/es/partidos/a96e4e26/Atletico-Madrid-Granada-Agosto-14-2023-La-Liga
# https://fbref.com/es/partidos/d447f323/Mallorca-Villarreal-Agosto-18-2023-La-Liga
# https://fbref.com/es/partidos/8766ab05/Valencia-Las-Palmas-Agosto-18-2023-La-Liga
# https://fbref.com/es/partidos/406ca8c9/Real-Sociedad-Celta-Vigo-Agosto-19-2023-La-Liga
# https://fbref.com/es/partidos/33737218/Almeria-Real-Madrid-Agosto-19-2023-La-Liga
# https://fbref.com/es/partidos/0df06b3f/Osasuna-Athletic-Club-Agosto-19-2023-La-Liga
# https://fbref.com/es/partidos/e8867e6b/Girona-Getafe-Agosto-20-2023-La-Liga
# https://fbref.com/es/partidos/312852e3/Barcelona-Cadiz-Agosto-20-2023-La-Liga
# https://fbref.com/es/partidos/95634760/Real-Betis-Atletico-Madrid-Agosto-20-2023-La-Liga
# https://fbref.com/es/partidos/8cd38a49/Alaves-Sevilla-Agosto-21-2023-La-Liga
# https://fbref.com/es/partidos/bc9648bc/Granada-Rayo-Vallecano-Agosto-21-2023-La-Liga
# https://fbref.com/es/partidos/b2340056/Las-Palmas-Real-Sociedad-Agosto-25-2023-La-Liga
# https://fbref.com/es/partidos/f414405a/Celta-Vigo-Real-Madrid-Agosto-25-2023-La-Liga
# https://fbref.com/es/partidos/6a02cbec/Cadiz-Almeria-Agosto-26-2023-La-Liga
# https://fbref.com/es/partidos/e249c708/Granada-Mallorca-Agosto-26-2023-La-Liga
# https://fbref.com/es/partidos/3aed0598/Sevilla-Girona-Agosto-26-2023-La-Liga
# https://fbref.com/es/partidos/b10c7abc/Villarreal-Barcelona-Agosto-27-2023-La-Liga
# https://fbref.com/es/partidos/804cc411/Valencia-Osasuna-Agosto-27-2023-La-Liga
# https://fbref.com/es/partidos/d99a5d06/Athletic-Club-Real-Betis-Agosto-27-2023-La-Liga
# https://fbref.com/es/partidos/74b34796/Getafe-Alaves-Agosto-28-2023-La-Liga
# https://fbref.com/es/partidos/bec04e9b/Rayo-Vallecano-Atletico-Madrid-Agosto-28-2023-La-Liga
# https://fbref.com/es/partidos/eb5232b2/Cadiz-Villarreal-Septiembre-1-2023-La-Liga
# https://fbref.com/es/partidos/979e8388/Almeria-Celta-Vigo-Septiembre-1-2023-La-Liga
# https://fbref.com/es/partidos/e1fd4178/Real-Sociedad-Granada-Septiembre-2-2023-La-Liga
# https://fbref.com/es/partidos/2b3c0a99/Real-Madrid-Getafe-Septiembre-2-2023-La-Liga
# https://fbref.com/es/partidos/3a3b9504/Alaves-Valencia-Septiembre-2-2023-La-Liga
# https://fbref.com/es/partidos/b11051a5/Real-Betis-Rayo-Vallecano-Septiembre-2-2023-La-Liga
# https://fbref.com/es/partidos/8dd16257/Girona-Las-Palmas-Septiembre-3-2023-La-Liga
# https://fbref.com/es/partidos/046e92d8/Mallorca-Athletic-Club-Septiembre-3-2023-La-Liga
# https://fbref.com/es/partidos/de343043/Osasuna-Barcelona-Septiembre-3-2023-La-Liga
# https://fbref.com/es/partidos/24453748/Rayo-Vallecano-Alaves-Septiembre-15-2023-La-Liga
# https://fbref.com/es/partidos/9b96c6da/Athletic-Club-Cadiz-Septiembre-16-2023-La-Liga
# https://fbref.com/es/partidos/26f7f1a6/Valencia-Atletico-Madrid-Septiembre-16-2023-La-Liga
# https://fbref.com/es/partidos/1e04d474/Celta-Vigo-Mallorca-Septiembre-16-2023-La-Liga
# https://fbref.com/es/partidos/91deddae/Barcelona-Real-Betis-Septiembre-16-2023-La-Liga
# https://fbref.com/es/partidos/c12983f1/Getafe-Osasuna-Septiembre-17-2023-La-Liga
# https://fbref.com/es/partidos/c16dfe0b/Villarreal-Almeria-Septiembre-17-2023-La-Liga
# https://fbref.com/es/partidos/b1d20065/Sevilla-Las-Palmas-Septiembre-17-2023-La-Liga
# https://fbref.com/es/partidos/c0a04549/Real-Madrid-Real-Sociedad-Septiembre-17-2023-La-Liga
# https://fbref.com/es/partidos/5f245c9f/Granada-Girona-Septiembre-18-2023-La-Liga
# https://fbref.com/es/partidos/b058555b/Alaves-Athletic-Club-Septiembre-22-2023-La-Liga
# https://fbref.com/es/partidos/d6d3de2f/Girona-Mallorca-Septiembre-23-2023-La-Liga
# https://fbref.com/es/partidos/72741505/Osasuna-Sevilla-Septiembre-23-2023-La-Liga
# https://fbref.com/es/partidos/027eed9e/Barcelona-Celta-Vigo-Septiembre-23-2023-La-Liga
# https://fbref.com/es/partidos/e5d13d76/Almeria-Valencia-Septiembre-23-2023-La-Liga
# https://fbref.com/es/partidos/3e8c7ee8/Real-Sociedad-Getafe-Septiembre-24-2023-La-Liga
# https://fbref.com/es/partidos/3ad7ddfb/Rayo-Vallecano-Villarreal-Septiembre-24-2023-La-Liga
# https://fbref.com/es/partidos/0cfa1fb6/Las-Palmas-Granada-Septiembre-24-2023-La-Liga
# https://fbref.com/es/partidos/a41377f4/Real-Betis-Cadiz-Septiembre-24-2023-La-Liga
# https://fbref.com/es/partidos/f535ba0a/El-Derbi-Madrileno-Atletico-Madrid-Real-Madrid-Septiembre-24-2023-La-Liga
# https://fbref.com/es/partidos/1a0a12f3/Sevilla-Almeria-Septiembre-26-2023-La-Liga
# https://fbref.com/es/partidos/c95852d8/Mallorca-Barcelona-Septiembre-26-2023-La-Liga
# https://fbref.com/es/partidos/5541c885/Athletic-Club-Getafe-Septiembre-27-2023-La-Liga
# https://fbref.com/es/partidos/73c339f6/Real-Madrid-Las-Palmas-Septiembre-27-2023-La-Liga
# https://fbref.com/es/partidos/7c83c807/Villarreal-Girona-Septiembre-27-2023-La-Liga
# https://fbref.com/es/partidos/2d774dd9/Cadiz-Rayo-Vallecano-Septiembre-27-2023-La-Liga
# https://fbref.com/es/partidos/572551e5/Valencia-Real-Sociedad-Septiembre-27-2023-La-Liga
# https://fbref.com/es/partidos/4f005fa8/Celta-Vigo-Alaves-Septiembre-28-2023-La-Liga
# https://fbref.com/es/partidos/6f6cb00d/Granada-Real-Betis-Septiembre-28-2023-La-Liga
# https://fbref.com/es/partidos/006cb34c/Osasuna-Atletico-Madrid-Septiembre-28-2023-La-Liga
# https://fbref.com/es/partidos/c5fbae8a/Barcelona-Sevilla-Septiembre-29-2023-La-Liga
# https://fbref.com/es/partidos/2fbd5e47/Getafe-Villarreal-Septiembre-30-2023-La-Liga
# https://fbref.com/es/partidos/32801dbc/Rayo-Vallecano-Mallorca-Septiembre-30-2023-La-Liga
# https://fbref.com/es/partidos/253621ab/Girona-Real-Madrid-Septiembre-30-2023-La-Liga
# https://fbref.com/es/partidos/9689cb22/Real-Sociedad-Athletic-Club-Septiembre-30-2023-La-Liga
# https://fbref.com/es/partidos/dd504406/Almeria-Granada-Octubre-1-2023-La-Liga
# https://fbref.com/es/partidos/3d120d0b/Alaves-Osasuna-Octubre-1-2023-La-Liga
# https://fbref.com/es/partidos/0f112739/Atletico-Madrid-Cadiz-Octubre-1-2023-La-Liga
# https://fbref.com/es/partidos/5668709c/Real-Betis-Valencia-Octubre-1-2023-La-Liga
# https://fbref.com/es/partidos/b5b5ee07/Las-Palmas-Celta-Vigo-Octubre-2-2023-La-Liga
# https://fbref.com/es/partidos/001383d7/Athletic-Club-Almeria-Octubre-6-2023-La-Liga
# https://fbref.com/es/partidos/2459c550/Cadiz-Girona-Octubre-7-2023-La-Liga
# https://fbref.com/es/partidos/cf81ed94/Real-Madrid-Osasuna-Octubre-7-2023-La-Liga
# https://fbref.com/es/partidos/65eed22a/Mallorca-Valencia-Octubre-7-2023-La-Liga
# https://fbref.com/es/partidos/faf557c5/Sevilla-Rayo-Vallecano-Octubre-7-2023-La-Liga
# https://fbref.com/es/partidos/539efe2f/Villarreal-Las-Palmas-Octubre-8-2023-La-Liga
# https://fbref.com/es/partidos/d0fec34b/Atletico-Madrid-Real-Sociedad-Octubre-8-2023-La-Liga
# https://fbref.com/es/partidos/68a32c10/Alaves-Real-Betis-Octubre-8-2023-La-Liga
# https://fbref.com/es/partidos/deb9ac58/Celta-Vigo-Getafe-Octubre-8-2023-La-Liga
# https://fbref.com/es/partidos/e2ce9278/Granada-Barcelona-Octubre-8-2023-La-Liga
# https://fbref.com/es/partidos/43b34260/Osasuna-Granada-Octubre-20-2023-La-Liga
# https://fbref.com/es/partidos/a4774fc2/Real-Sociedad-Mallorca-Octubre-21-2023-La-Liga
# https://fbref.com/es/partidos/0d187cb4/Getafe-Real-Betis-Octubre-21-2023-La-Liga
# https://fbref.com/es/partidos/a1453e00/Sevilla-Real-Madrid-Octubre-21-2023-La-Liga
# https://fbref.com/es/partidos/7e7af068/Celta-Vigo-Atletico-Madrid-Octubre-21-2023-La-Liga
# https://fbref.com/es/partidos/75aaa3ef/Las-Palmas-Rayo-Vallecano-Octubre-22-2023-La-Liga
# https://fbref.com/es/partidos/eadb4a85/Girona-Almeria-Octubre-22-2023-La-Liga
# https://fbref.com/es/partidos/f86dfb97/Villarreal-Alaves-Octubre-22-2023-La-Liga
# https://fbref.com/es/partidos/5be40f3e/Barcelona-Athletic-Club-Octubre-22-2023-La-Liga
# https://fbref.com/es/partidos/39c4605e/Valencia-Cadiz-Octubre-23-2023-La-Liga
# https://fbref.com/es/partidos/390bde4a/Girona-Celta-Vigo-Octubre-27-2023-La-Liga
# https://fbref.com/es/partidos/22d80391/Almeria-Las-Palmas-Octubre-28-2023-La-Liga
# https://fbref.com/es/partidos/59b0e4f0/El-Clasico-Barcelona-Real-Madrid-Octubre-28-2023-La-Liga
# https://fbref.com/es/partidos/eda40c8e/Mallorca-Getafe-Octubre-28-2023-La-Liga
# https://fbref.com/es/partidos/11176e0f/Cadiz-Sevilla-Octubre-28-2023-La-Liga
# https://fbref.com/es/partidos/0c248bda/Real-Betis-Osasuna-Octubre-29-2023-La-Liga
# https://fbref.com/es/partidos/0e7c5910/Rayo-Vallecano-Real-Sociedad-Octubre-29-2023-La-Liga
# https://fbref.com/es/partidos/73bdd066/Athletic-Club-Valencia-Octubre-29-2023-La-Liga
# https://fbref.com/es/partidos/a4771eec/Atletico-Madrid-Alaves-Octubre-29-2023-La-Liga
# https://fbref.com/es/partidos/c3aa20c5/Granada-Villarreal-Octubre-30-2023-La-Liga
# https://fbref.com/es/partidos/52e1b035/Las-Palmas-Atletico-Madrid-Noviembre-3-2023-La-Liga
# https://fbref.com/es/partidos/2060ad55/Osasuna-Girona-Noviembre-4-2023-La-Liga
# https://fbref.com/es/partidos/0d1db511/Real-Betis-Mallorca-Noviembre-4-2023-La-Liga
# https://fbref.com/es/partidos/133dffca/Celta-Vigo-Sevilla-Noviembre-4-2023-La-Liga
# https://fbref.com/es/partidos/a81185c4/Real-Sociedad-Barcelona-Noviembre-4-2023-La-Liga
# https://fbref.com/es/partidos/f68f1f5c/Alaves-Almeria-Noviembre-5-2023-La-Liga
# https://fbref.com/es/partidos/6bc552c2/Valencia-Granada-Noviembre-5-2023-La-Liga
# https://fbref.com/es/partidos/d3edf2ae/Villarreal-Athletic-Club-Noviembre-5-2023-La-Liga
# https://fbref.com/es/partidos/ff452d69/Real-Madrid-Rayo-Vallecano-Noviembre-5-2023-La-Liga
# https://fbref.com/es/partidos/ed5f02e2/Getafe-Cadiz-Noviembre-6-2023-La-Liga
# https://fbref.com/es/partidos/bdde04ef/Athletic-Club-Celta-Vigo-Noviembre-10-2023-La-Liga
# https://fbref.com/es/partidos/5f383bb2/Rayo-Vallecano-Girona-Noviembre-11-2023-La-Liga
# https://fbref.com/es/partidos/499da981/Almeria-Real-Sociedad-Noviembre-11-2023-La-Liga
# https://fbref.com/es/partidos/52845bb5/Osasuna-Las-Palmas-Noviembre-11-2023-La-Liga
# https://fbref.com/es/partidos/da4c3931/Granada-Getafe-Noviembre-11-2023-La-Liga
# https://fbref.com/es/partidos/1cb4d5cc/Real-Madrid-Valencia-Noviembre-11-2023-La-Liga
# https://fbref.com/es/partidos/3541e819/Barcelona-Alaves-Noviembre-12-2023-La-Liga
# https://fbref.com/es/partidos/f4e8506b/Sevilla-Real-Betis-Noviembre-12-2023-La-Liga
# https://fbref.com/es/partidos/cadb3e6a/Atletico-Madrid-Villarreal-Noviembre-12-2023-La-Liga
# https://fbref.com/es/partidos/7e1b64b6/Alaves-Granada-Noviembre-24-2023-La-Liga
# https://fbref.com/es/partidos/01f34256/Rayo-Vallecano-Barcelona-Noviembre-25-2023-La-Liga
# https://fbref.com/es/partidos/c7b4a2f1/Valencia-Celta-Vigo-Noviembre-25-2023-La-Liga
# https://fbref.com/es/partidos/db6cf568/Getafe-Almeria-Noviembre-25-2023-La-Liga
# https://fbref.com/es/partidos/16b9ac5f/Atletico-Madrid-Mallorca-Noviembre-25-2023-La-Liga
# https://fbref.com/es/partidos/39aeccb8/Villarreal-Osasuna-Noviembre-26-2023-La-Liga
# https://fbref.com/es/partidos/6693ba62/Real-Sociedad-Sevilla-Noviembre-26-2023-La-Liga
# https://fbref.com/es/partidos/5d52e4e2/Cadiz-Real-Madrid-Noviembre-26-2023-La-Liga
# https://fbref.com/es/partidos/835e91b9/Real-Betis-Las-Palmas-Noviembre-26-2023-La-Liga
# https://fbref.com/es/partidos/aef6bb51/Girona-Athletic-Club-Noviembre-27-2023-La-Liga
# https://fbref.com/es/partidos/12f1bd76/Mallorca-Cadiz-Noviembre-29-2023-La-Liga
# https://fbref.com/es/partidos/43a9a3f9/Las-Palmas-Getafe-Diciembre-1-2023-La-Liga
# https://fbref.com/es/partidos/3a6cf7d9/Girona-Valencia-Diciembre-2-2023-La-Liga
# https://fbref.com/es/partidos/b88a35df/Athletic-Club-Rayo-Vallecano-Diciembre-2-2023-La-Liga
# https://fbref.com/es/partidos/bc316609/Real-Madrid-Granada-Diciembre-2-2023-La-Liga
# https://fbref.com/es/partidos/5d28eb72/Osasuna-Real-Sociedad-Diciembre-2-2023-La-Liga
# https://fbref.com/es/partidos/aa2065ac/Mallorca-Alaves-Diciembre-3-2023-La-Liga
# https://fbref.com/es/partidos/90d64d3b/Almeria-Real-Betis-Diciembre-3-2023-La-Liga
# https://fbref.com/es/partidos/98ae1fe6/Sevilla-Villarreal-Diciembre-3-2023-La-Liga
# https://fbref.com/es/partidos/0012462a/Barcelona-Atletico-Madrid-Diciembre-3-2023-La-Liga
# https://fbref.com/es/partidos/2618d749/Celta-Vigo-Cadiz-Diciembre-4-2023-La-Liga
# https://fbref.com/es/partidos/ecf11fd1/Getafe-Valencia-Diciembre-8-2023-La-Liga
# https://fbref.com/es/partidos/06bb7e90/Alaves-Las-Palmas-Diciembre-9-2023-La-Liga
# https://fbref.com/es/partidos/872da7fb/Real-Betis-Real-Madrid-Diciembre-9-2023-La-Liga
# https://fbref.com/es/partidos/7c91b9cb/Villarreal-Real-Sociedad-Diciembre-9-2023-La-Liga
# https://fbref.com/es/partidos/7dacfd9b/Mallorca-Sevilla-Diciembre-9-2023-La-Liga
# https://fbref.com/es/partidos/381f0556/Atletico-Madrid-Almeria-Diciembre-10-2023-La-Liga
# https://fbref.com/es/partidos/7c80b72c/Cadiz-Osasuna-Diciembre-10-2023-La-Liga
# https://fbref.com/es/partidos/36e35f1b/Barcelona-Girona-Diciembre-10-2023-La-Liga
# https://fbref.com/es/partidos/2e13f78e/Granada-Athletic-Club-Diciembre-11-2023-La-Liga
# https://fbref.com/es/partidos/8561242b/Rayo-Vallecano-Celta-Vigo-Diciembre-11-2023-La-Liga
# https://fbref.com/es/partidos/781d0d19/Osasuna-Rayo-Vallecano-Diciembre-15-2023-La-Liga
# https://fbref.com/es/partidos/57110974/Celta-Vigo-Granada-Diciembre-16-2023-La-Liga
# https://fbref.com/es/partidos/f21edbdb/Athletic-Club-Atletico-Madrid-Diciembre-16-2023-La-Liga
# https://fbref.com/es/partidos/4d8d0ba8/Sevilla-Getafe-Diciembre-16-2023-La-Liga
# https://fbref.com/es/partidos/ab58d4c0/Valencia-Barcelona-Diciembre-16-2023-La-Liga
# https://fbref.com/es/partidos/29830e6b/Almeria-Mallorca-Diciembre-17-2023-La-Liga
# https://fbref.com/es/partidos/5c3fe234/Real-Sociedad-Real-Betis-Diciembre-17-2023-La-Liga
# https://fbref.com/es/partidos/08036869/Las-Palmas-Cadiz-Diciembre-17-2023-La-Liga
# https://fbref.com/es/partidos/7cbfb8ee/Real-Madrid-Villarreal-Diciembre-17-2023-La-Liga
# https://fbref.com/es/partidos/b26778b7/Girona-Alaves-Diciembre-18-2023-La-Liga
# https://fbref.com/es/partidos/25af4fd3/Rayo-Vallecano-Valencia-Diciembre-19-2023-La-Liga
# https://fbref.com/es/partidos/23fb1e35/Atletico-Madrid-Getafe-Diciembre-19-2023-La-Liga
# https://fbref.com/es/partidos/9a19af2d/Granada-Sevilla-Diciembre-19-2023-La-Liga
# https://fbref.com/es/partidos/cb6ccdca/Barcelona-Almeria-Diciembre-20-2023-La-Liga
# https://fbref.com/es/partidos/1b8fc92b/Athletic-Club-Las-Palmas-Diciembre-20-2023-La-Liga
# https://fbref.com/es/partidos/9f6ecef6/Villarreal-Celta-Vigo-Diciembre-20-2023-La-Liga
# https://fbref.com/es/partidos/58612cde/Cadiz-Real-Sociedad-Diciembre-21-2023-La-Liga
# https://fbref.com/es/partidos/ce152000/Real-Betis-Girona-Diciembre-21-2023-La-Liga
# https://fbref.com/es/partidos/4dec0026/Alaves-Real-Madrid-Diciembre-21-2023-La-Liga
# https://fbref.com/es/partidos/cc0b697d/Mallorca-Osasuna-Diciembre-21-2023-La-Liga
# https://fbref.com/es/partidos/8797c007/Atletico-Madrid-Sevilla-Diciembre-23-2023-La-Liga
# https://fbref.com/es/partidos/be4710dc/Getafe-Rayo-Vallecano-Enero-2-2024-La-Liga
# https://fbref.com/es/partidos/57a94079/Real-Sociedad-Alaves-Enero-2-2024-La-Liga
# https://fbref.com/es/partidos/2a5dbe16/Valencia-Villarreal-Enero-2-2024-La-Liga
# https://fbref.com/es/partidos/81995a26/Granada-Cadiz-Enero-3-2024-La-Liga
# https://fbref.com/es/partidos/a68c4db0/Real-Madrid-Mallorca-Enero-3-2024-La-Liga
# https://fbref.com/es/partidos/f235cb36/Celta-Vigo-Real-Betis-Enero-3-2024-La-Liga
# https://fbref.com/es/partidos/1a18f1be/Girona-Atletico-Madrid-Enero-3-2024-La-Liga
# https://fbref.com/es/partidos/2d6bd38e/Osasuna-Almeria-Enero-4-2024-La-Liga
# https://fbref.com/es/partidos/a599d8e1/Sevilla-Athletic-Club-Enero-4-2024-La-Liga
# https://fbref.com/es/partidos/2181388a/Las-Palmas-Barcelona-Enero-4-2024-La-Liga
# https://fbref.com/es/partidos/dacf8559/Sevilla-Alaves-Enero-12-2024-La-Liga
# https://fbref.com/es/partidos/2328243e/Las-Palmas-Villarreal-Enero-13-2024-La-Liga
# https://fbref.com/es/partidos/62bdac3e/Mallorca-Celta-Vigo-Enero-13-2024-La-Liga
# https://fbref.com/es/partidos/cbde4eb0/Athletic-Club-Real-Sociedad-Enero-13-2024-La-Liga
# https://fbref.com/es/partidos/b889c1e1/Real-Betis-Granada-Enero-13-2024-La-Liga
# https://fbref.com/es/partidos/ac070af0/Almeria-Girona-Enero-14-2024-La-Liga
# https://fbref.com/es/partidos/191bdef3/Cadiz-Valencia-Enero-14-2024-La-Liga
# https://fbref.com/es/partidos/06721bb2/Alaves-Cadiz-Enero-19-2024-La-Liga
# https://fbref.com/es/partidos/2de52681/Rayo-Vallecano-Las-Palmas-Enero-20-2024-La-Liga
# https://fbref.com/es/partidos/bf30b05f/Villarreal-Mallorca-Enero-20-2024-La-Liga
# https://fbref.com/es/partidos/56f618cb/Valencia-Athletic-Club-Enero-20-2024-La-Liga
# https://fbref.com/es/partidos/261b5161/Celta-Vigo-Real-Sociedad-Enero-20-2024-La-Liga
# https://fbref.com/es/partidos/92457ba9/Osasuna-Getafe-Enero-21-2024-La-Liga
# https://fbref.com/es/partidos/044f7144/Real-Madrid-Almeria-Enero-21-2024-La-Liga
# https://fbref.com/es/partidos/cd2367fb/Real-Betis-Barcelona-Enero-21-2024-La-Liga
# https://fbref.com/es/partidos/001f02ea/Girona-Sevilla-Enero-21-2024-La-Liga
# https://fbref.com/es/partidos/3cfa176f/Granada-Atletico-Madrid-Enero-22-2024-La-Liga
# https://fbref.com/es/partidos/851f5d85/Almeria-Alaves-Enero-26-2024-La-Liga
# https://fbref.com/es/partidos/72e78a1f/Real-Sociedad-Rayo-Vallecano-Enero-27-2024-La-Liga
# https://fbref.com/es/partidos/b61e3e2f/Las-Palmas-Real-Madrid-Enero-27-2024-La-Liga
# https://fbref.com/es/partidos/06120109/Barcelona-Villarreal-Enero-27-2024-La-Liga
# https://fbref.com/es/partidos/c9ebb8f9/Mallorca-Real-Betis-Enero-27-2024-La-Liga
# https://fbref.com/es/partidos/898ad853/Celta-Vigo-Girona-Enero-28-2024-La-Liga
# https://fbref.com/es/partidos/01dea01a/Cadiz-Athletic-Club-Enero-28-2024-La-Liga
# https://fbref.com/es/partidos/661915d5/Sevilla-Osasuna-Enero-28-2024-La-Liga
# https://fbref.com/es/partidos/fb9eb11a/Atletico-Madrid-Valencia-Enero-28-2024-La-Liga
# https://fbref.com/es/partidos/adf50a1d/Getafe-Granada-Enero-29-2024-La-Liga
# https://fbref.com/es/partidos/d6106b99/Barcelona-Osasuna-Enero-31-2024-La-Liga
# https://fbref.com/es/partidos/cbaaa323/Atletico-Madrid-Rayo-Vallecano-Enero-31-2024-La-Liga
# https://fbref.com/es/partidos/92a1197f/Getafe-Real-Madrid-Febrero-1-2024-La-Liga
# https://fbref.com/es/partidos/5f6e670c/Athletic-Club-Mallorca-Febrero-2-2024-La-Liga
# https://fbref.com/es/partidos/149141f2/Valencia-Almeria-Febrero-3-2024-La-Liga
# https://fbref.com/es/partidos/22e4db63/Granada-Las-Palmas-Febrero-3-2024-La-Liga
# https://fbref.com/es/partidos/37151033/Alaves-Barcelona-Febrero-3-2024-La-Liga
# https://fbref.com/es/partidos/92a239f6/Girona-Real-Sociedad-Febrero-3-2024-La-Liga
# https://fbref.com/es/partidos/28a20450/Villarreal-Cadiz-Febrero-4-2024-La-Liga
# https://fbref.com/es/partidos/b8fec464/Osasuna-Celta-Vigo-Febrero-4-2024-La-Liga
# https://fbref.com/es/partidos/faf7791c/Real-Betis-Getafe-Febrero-4-2024-La-Liga
# https://fbref.com/es/partidos/199f13ef/El-Derbi-Madrileno-Real-Madrid-Atletico-Madrid-Febrero-4-2024-La-Liga
# https://fbref.com/es/partidos/1c2d13c4/Rayo-Vallecano-Sevilla-Febrero-5-2024-La-Liga
# https://fbref.com/es/partidos/4853d9e5/Cadiz-Real-Betis-Febrero-9-2024-La-Liga
# https://fbref.com/es/partidos/df1c317c/Alaves-Villarreal-Febrero-10-2024-La-Liga
# https://fbref.com/es/partidos/38ef643d/Real-Sociedad-Osasuna-Febrero-10-2024-La-Liga
# https://fbref.com/es/partidos/501f00a9/Real-Madrid-Girona-Febrero-10-2024-La-Liga
# https://fbref.com/es/partidos/8635863c/Las-Palmas-Valencia-Febrero-10-2024-La-Liga
# https://fbref.com/es/partidos/93f25b56/Getafe-Celta-Vigo-Febrero-11-2024-La-Liga
# https://fbref.com/es/partidos/35c12a15/Mallorca-Rayo-Vallecano-Febrero-11-2024-La-Liga
# https://fbref.com/es/partidos/dd0585e1/Sevilla-Atletico-Madrid-Febrero-11-2024-La-Liga
# https://fbref.com/es/partidos/02934208/Barcelona-Granada-Febrero-11-2024-La-Liga
# https://fbref.com/es/partidos/aadff460/Almeria-Athletic-Club-Febrero-12-2024-La-Liga
# https://fbref.com/es/partidos/39eb65ce/Villarreal-Getafe-Febrero-16-2024-La-Liga
# https://fbref.com/es/partidos/d2e1cfdb/Atletico-Madrid-Las-Palmas-Febrero-17-2024-La-Liga
# https://fbref.com/es/partidos/acb216f1/Osasuna-Cadiz-Febrero-17-2024-La-Liga
# https://fbref.com/es/partidos/16accf14/Celta-Vigo-Barcelona-Febrero-17-2024-La-Liga
# https://fbref.com/es/partidos/9beaaafb/Valencia-Sevilla-Febrero-17-2024-La-Liga
# https://fbref.com/es/partidos/8f2c26c1/Rayo-Vallecano-Real-Madrid-Febrero-18-2024-La-Liga
# https://fbref.com/es/partidos/5843757f/Granada-Almeria-Febrero-18-2024-La-Liga
# https://fbref.com/es/partidos/f19651ab/Mallorca-Real-Sociedad-Febrero-18-2024-La-Liga
# https://fbref.com/es/partidos/b8a430ca/Real-Betis-Alaves-Febrero-18-2024-La-Liga
# https://fbref.com/es/partidos/cab3844e/Athletic-Club-Girona-Febrero-19-2024-La-Liga
# https://fbref.com/es/partidos/4c975b7e/Real-Sociedad-Villarreal-Febrero-23-2024-La-Liga
# https://fbref.com/es/partidos/8f4e2ab7/Barcelona-Getafe-Febrero-24-2024-La-Liga
# https://fbref.com/es/partidos/24435ef9/Alaves-Mallorca-Febrero-24-2024-La-Liga
# https://fbref.com/es/partidos/998ad495/Almeria-Atletico-Madrid-Febrero-24-2024-La-Liga
# https://fbref.com/es/partidos/81b6bcdb/Cadiz-Celta-Vigo-Febrero-25-2024-La-Liga
# https://fbref.com/es/partidos/05f0bbdc/Real-Betis-Athletic-Club-Febrero-25-2024-La-Liga
# https://fbref.com/es/partidos/cbe1823a/Las-Palmas-Osasuna-Febrero-25-2024-La-Liga
# https://fbref.com/es/partidos/0788c1f1/Real-Madrid-Sevilla-Febrero-25-2024-La-Liga
# https://fbref.com/es/partidos/a07bda86/Girona-Rayo-Vallecano-Febrero-26-2024-La-Liga
# https://fbref.com/es/partidos/7ab6dcd9/Celta-Vigo-Almeria-Marzo-1-2024-La-Liga
# https://fbref.com/es/partidos/94990b76/Sevilla-Real-Sociedad-Marzo-2-2024-La-Liga
# https://fbref.com/es/partidos/f374824a/Rayo-Vallecano-Cadiz-Marzo-2-2024-La-Liga
# https://fbref.com/es/partidos/1f2c17eb/Getafe-Las-Palmas-Marzo-2-2024-La-Liga
# https://fbref.com/es/partidos/2e5cdea9/Valencia-Real-Madrid-Marzo-2-2024-La-Liga
# https://fbref.com/es/partidos/82279c7a/Villarreal-Granada-Marzo-3-2024-La-Liga
# https://fbref.com/es/partidos/f887328c/Atletico-Madrid-Real-Betis-Marzo-3-2024-La-Liga
# https://fbref.com/es/partidos/43ea52c2/Mallorca-Girona-Marzo-3-2024-La-Liga
# https://fbref.com/es/partidos/8c7d46b8/Athletic-Club-Barcelona-Marzo-3-2024-La-Liga
# https://fbref.com/es/partidos/9bee2dfe/Osasuna-Alaves-Marzo-4-2024-La-Liga
# https://fbref.com/es/partidos/893d91cd/Barcelona-Mallorca-Marzo-8-2024-La-Liga
# https://fbref.com/es/partidos/f3a99bc6/Valencia-Getafe-Marzo-9-2024-La-Liga
# https://fbref.com/es/partidos/4626c60c/Cadiz-Atletico-Madrid-Marzo-9-2024-La-Liga
# https://fbref.com/es/partidos/68564a87/Granada-Real-Sociedad-Marzo-9-2024-La-Liga
# https://fbref.com/es/partidos/0778b3ab/Girona-Osasuna-Marzo-9-2024-La-Liga
# https://fbref.com/es/partidos/fd381a48/Alaves-Rayo-Vallecano-Marzo-10-2024-La-Liga
# https://fbref.com/es/partidos/c5876baa/Las-Palmas-Athletic-Club-Marzo-10-2024-La-Liga
# https://fbref.com/es/partidos/e829e739/Real-Madrid-Celta-Vigo-Marzo-10-2024-La-Liga
# https://fbref.com/es/partidos/a9c711a7/Real-Betis-Villarreal-Marzo-10-2024-La-Liga
# https://fbref.com/es/partidos/b60cb69e/Almeria-Sevilla-Marzo-11-2024-La-Liga
# https://fbref.com/es/partidos/f6be96b2/Real-Sociedad-Cadiz-Marzo-15-2024-La-Liga
# https://fbref.com/es/partidos/62e3bbb2/Mallorca-Granada-Marzo-16-2024-La-Liga
# https://fbref.com/es/partidos/132fdf9c/Osasuna-Real-Madrid-Marzo-16-2024-La-Liga
# https://fbref.com/es/partidos/a0f615f1/Getafe-Girona-Marzo-16-2024-La-Liga
# https://fbref.com/es/partidos/353fc7dc/Athletic-Club-Alaves-Marzo-16-2024-La-Liga
# https://fbref.com/es/partidos/677dc25e/Sevilla-Celta-Vigo-Marzo-17-2024-La-Liga
# https://fbref.com/es/partidos/09fcfcbf/Las-Palmas-Almeria-Marzo-17-2024-La-Liga
# https://fbref.com/es/partidos/d88d960f/Villarreal-Valencia-Marzo-17-2024-La-Liga
# https://fbref.com/es/partidos/8ace3465/Rayo-Vallecano-Real-Betis-Marzo-17-2024-La-Liga
# https://fbref.com/es/partidos/bccce279/Atletico-Madrid-Barcelona-Marzo-17-2024-La-Liga
# https://fbref.com/es/partidos/8b40ebf8/Cadiz-Granada-Marzo-29-2024-La-Liga
# https://fbref.com/es/partidos/225535f4/Getafe-Sevilla-Marzo-30-2024-La-Liga
# https://fbref.com/es/partidos/2faf48dd/Almeria-Osasuna-Marzo-30-2024-La-Liga
# https://fbref.com/es/partidos/d9329662/Valencia-Mallorca-Marzo-30-2024-La-Liga
# https://fbref.com/es/partidos/0ba647fb/Barcelona-Las-Palmas-Marzo-30-2024-La-Liga
# https://fbref.com/es/partidos/b407fe75/Celta-Vigo-Rayo-Vallecano-Marzo-31-2024-La-Liga
# https://fbref.com/es/partidos/43f30f97/Girona-Real-Betis-Marzo-31-2024-La-Liga
# https://fbref.com/es/partidos/47e43855/Alaves-Real-Sociedad-Marzo-31-2024-La-Liga
# https://fbref.com/es/partidos/cb8f8470/Real-Madrid-Athletic-Club-Marzo-31-2024-La-Liga
# https://fbref.com/es/partidos/ea244c20/Villarreal-Atletico-Madrid-Abril-1-2024-La-Liga
# https://fbref.com/es/partidos/e8f66280/Granada-Valencia-Abril-4-2024-La-Liga
# https://fbref.com/es/partidos/a7ba44ee/Real-Betis-Celta-Vigo-Abril-12-2024-La-Liga
# https://fbref.com/es/partidos/d1461be3/Atletico-Madrid-Girona-Abril-13-2024-La-Liga
# https://fbref.com/es/partidos/1ebfb4e4/Rayo-Vallecano-Getafe-Abril-13-2024-La-Liga
# https://fbref.com/es/partidos/8887cd3f/Mallorca-Real-Madrid-Abril-13-2024-La-Liga
# https://fbref.com/es/partidos/a4bd2f2a/Cadiz-Barcelona-Abril-13-2024-La-Liga
# https://fbref.com/es/partidos/5a35c6d1/Las-Palmas-Sevilla-Abril-14-2024-La-Liga
# https://fbref.com/es/partidos/f08ebff7/Granada-Alaves-Abril-14-2024-La-Liga
# https://fbref.com/es/partidos/941a4629/Athletic-Club-Villarreal-Abril-14-2024-La-Liga
# https://fbref.com/es/partidos/32b50c2a/Real-Sociedad-Almeria-Abril-14-2024-La-Liga
# https://fbref.com/es/partidos/47963fdb/Osasuna-Valencia-Abril-15-2024-La-Liga
# https://fbref.com/es/partidos/77710902/Athletic-Club-Granada-Abril-19-2024-La-Liga
# https://fbref.com/es/partidos/a3ba5e25/Celta-Vigo-Las-Palmas-Abril-20-2024-La-Liga
# https://fbref.com/es/partidos/cbed4286/Rayo-Vallecano-Osasuna-Abril-20-2024-La-Liga
# https://fbref.com/es/partidos/746db3ae/Valencia-Real-Betis-Abril-20-2024-La-Liga
# https://fbref.com/es/partidos/6e1ed9b8/Girona-Cadiz-Abril-20-2024-La-Liga
# https://fbref.com/es/partidos/c0cdba0e/Getafe-Real-Sociedad-Abril-21-2024-La-Liga
# https://fbref.com/es/partidos/635dcbf9/Almeria-Villarreal-Abril-21-2024-La-Liga
# https://fbref.com/es/partidos/b40183ad/Alaves-Atletico-Madrid-Abril-21-2024-La-Liga
# https://fbref.com/es/partidos/9699d0ae/El-Clasico-Real-Madrid-Barcelona-Abril-21-2024-La-Liga
# https://fbref.com/es/partidos/2d5046e6/Sevilla-Mallorca-Abril-22-2024-La-Liga
# https://fbref.com/es/partidos/3edf4d41/Real-Sociedad-Real-Madrid-Abril-26-2024-La-Liga
# https://fbref.com/es/partidos/e996fa16/Las-Palmas-Girona-Abril-27-2024-La-Liga
# https://fbref.com/es/partidos/54592e27/Almeria-Getafe-Abril-27-2024-La-Liga
# https://fbref.com/es/partidos/ffe34927/Alaves-Celta-Vigo-Abril-27-2024-La-Liga
# https://fbref.com/es/partidos/a0a9d4cf/Atletico-Madrid-Athletic-Club-Abril-27-2024-La-Liga
# https://fbref.com/es/partidos/05b862fc/Cadiz-Mallorca-Abril-28-2024-La-Liga
# https://fbref.com/es/partidos/7e063e40/Granada-Osasuna-Abril-28-2024-La-Liga
# https://fbref.com/es/partidos/9db220c0/Villarreal-Rayo-Vallecano-Abril-28-2024-La-Liga
# https://fbref.com/es/partidos/94a4da32/Real-Betis-Sevilla-Abril-28-2024-La-Liga
# https://fbref.com/es/partidos/c5942116/Barcelona-Valencia-Abril-29-2024-La-Liga
# https://fbref.com/es/partidos/506b1b2a/Getafe-Athletic-Club-Mayo-3-2024-La-Liga
# https://fbref.com/es/partidos/386210a4/Real-Sociedad-Las-Palmas-Mayo-4-2024-La-Liga
# https://fbref.com/es/partidos/ac0f607f/Real-Madrid-Cadiz-Mayo-4-2024-La-Liga
# https://fbref.com/es/partidos/2857168f/Girona-Barcelona-Mayo-4-2024-La-Liga
# https://fbref.com/es/partidos/53936afb/Mallorca-Atletico-Madrid-Mayo-4-2024-La-Liga
# https://fbref.com/es/partidos/4c79cbf6/Osasuna-Real-Betis-Mayo-5-2024-La-Liga
# https://fbref.com/es/partidos/429fcafb/Celta-Vigo-Villarreal-Mayo-5-2024-La-Liga
# https://fbref.com/es/partidos/3c4e6a04/Valencia-Alaves-Mayo-5-2024-La-Liga
# https://fbref.com/es/partidos/6515a447/Rayo-Vallecano-Almeria-Mayo-5-2024-La-Liga
# https://fbref.com/es/partidos/cf65828c/Sevilla-Granada-Mayo-5-2024-La-Liga
# https://fbref.com/es/partidos/8d5472e3/Alaves-Girona-Mayo-10-2024-La-Liga
# https://fbref.com/es/partidos/b4349d20/Mallorca-Las-Palmas-Mayo-11-2024-La-Liga
# https://fbref.com/es/partidos/db2c3f5d/Villarreal-Sevilla-Mayo-11-2024-La-Liga
# https://fbref.com/es/partidos/fa49110c/Granada-Real-Madrid-Mayo-11-2024-La-Liga
# https://fbref.com/es/partidos/da28b0d1/Athletic-Club-Osasuna-Mayo-11-2024-La-Liga
# https://fbref.com/es/partidos/20329c38/Cadiz-Getafe-Mayo-12-2024-La-Liga
# https://fbref.com/es/partidos/b2f7f5e0/Atletico-Madrid-Celta-Vigo-Mayo-12-2024-La-Liga
# https://fbref.com/es/partidos/a0fb8424/Valencia-Rayo-Vallecano-Mayo-12-2024-La-Liga
# https://fbref.com/es/partidos/78324d14/Real-Betis-Almeria-Mayo-12-2024-La-Liga
# https://fbref.com/es/partidos/3d94f1a4/Barcelona-Real-Sociedad-Mayo-13-2024-La-Liga
# https://fbref.com/es/partidos/e3feee7a/Osasuna-Mallorca-Mayo-14-2024-La-Liga
# https://fbref.com/es/partidos/33a6634e/Real-Madrid-Alaves-Mayo-14-2024-La-Liga
# https://fbref.com/es/partidos/34cead76/Girona-Villarreal-Mayo-14-2024-La-Liga
# https://fbref.com/es/partidos/ed81748f/Rayo-Vallecano-Granada-Mayo-15-2024-La-Liga
# https://fbref.com/es/partidos/fe5dae8c/Sevilla-Cadiz-Mayo-15-2024-La-Liga
# https://fbref.com/es/partidos/15d304e7/Celta-Vigo-Athletic-Club-Mayo-15-2024-La-Liga
# https://fbref.com/es/partidos/696d137e/Getafe-Atletico-Madrid-Mayo-15-2024-La-Liga
# https://fbref.com/es/partidos/6927b08f/Las-Palmas-Real-Betis-Mayo-16-2024-La-Liga
# https://fbref.com/es/partidos/78ebb2dd/Almeria-Barcelona-Mayo-16-2024-La-Liga
# https://fbref.com/es/partidos/e2a89f33/Real-Sociedad-Valencia-Mayo-16-2024-La-Liga
# https://fbref.com/es/partidos/7c178e2f/Alaves-Getafe-Mayo-18-2024-La-Liga
# https://fbref.com/es/partidos/113ce588/Atletico-Madrid-Osasuna-Mayo-19-2024-La-Liga
# https://fbref.com/es/partidos/4691300c/Athletic-Club-Sevilla-Mayo-19-2024-La-Liga
# https://fbref.com/es/partidos/668bdcc1/Real-Betis-Real-Sociedad-Mayo-19-2024-La-Liga
# https://fbref.com/es/partidos/a07daf85/Barcelona-Rayo-Vallecano-Mayo-19-2024-La-Liga
# https://fbref.com/es/partidos/ab933e0a/Mallorca-Almeria-Mayo-19-2024-La-Liga
# https://fbref.com/es/partidos/bcfed537/Granada-Celta-Vigo-Mayo-19-2024-La-Liga
# https://fbref.com/es/partidos/c66a2814/Valencia-Girona-Mayo-19-2024-La-Liga
# https://fbref.com/es/partidos/db3b593e/Cadiz-Las-Palmas-Mayo-19-2024-La-Liga
# https://fbref.com/es/partidos/ec275e77/Villarreal-Real-Madrid-Mayo-19-2024-La-Liga
# https://fbref.com/es/partidos/0b569a97/Girona-Granada-Mayo-24-2024-La-Liga
# https://fbref.com/es/partidos/ecd762d7/Osasuna-Villarreal-Mayo-25-2024-La-Liga
# https://fbref.com/es/partidos/b4cbdba3/Real-Sociedad-Atletico-Madrid-Mayo-25-2024-La-Liga
# https://fbref.com/es/partidos/3deb8202/Almeria-Cadiz-Mayo-25-2024-La-Liga
# https://fbref.com/es/partidos/79f108d8/Rayo-Vallecano-Athletic-Club-Mayo-25-2024-La-Liga
# https://fbref.com/es/partidos/b4858ba8/Real-Madrid-Real-Betis-Mayo-25-2024-La-Liga
# https://fbref.com/es/partidos/452075d1/Getafe-Mallorca-Mayo-26-2024-La-Liga
# https://fbref.com/es/partidos/d052dfe0/Las-Palmas-Alaves-Mayo-26-2024-La-Liga
# https://fbref.com/es/partidos/f43e7cfe/Celta-Vigo-Valencia-Mayo-26-2024-La-Liga
# https://fbref.com/es/partidos/e45b3740/Sevilla-Barcelona-Mayo-26-2024-La-Liga
